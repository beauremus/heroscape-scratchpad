# %%
import csv
import pickle
from datetime import datetime
from pathlib import Path
from characters import Character
from characters import Card
from heroscape import HeadToHead

# %%
cards = {}
trials = 10

# %%
with open('heroscape-characters.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        characters = []
        suffix = ''
        
        for character_count in range(int(row['Number'])):
            if int(row['Number']) > 1:
                suffix = f' {character_count + 1}'

            characters.append(Character(f'{row["Name"]}{suffix}', int(row['Life']), int(row['Attack']), int(row['Defense'])))
            
        cards[row['Name']] = Card(row['Name'], int(row['Attack']), int(row['Defense']), characters)

# %%
for first_card in cards:
    for second_card in cards:
        if first_card != second_card:
            for _ in range(trials):
                HeadToHead(cards[first_card], cards[second_card]).resolve()
                cards[first_card].revive()
                cards[second_card].revive()

# %%
for card in cards:
    print(f'{cards[card].name}: wins - {cards[card].wins["total"]} losses - {cards[card].losses["total"]}')
# Out:
# Deathreavers: wins - 0 losses - 1
# Zettian Guards: wins - 3 losses - 1
# Isamu: wins - 0 losses - 1
# Blastatrons: wins - 0 losses - 1
# Knights of Weston: wins - 4 losses - 1
# Heavy Gruts: wins - 0 losses - 1
# 4th Massachusetts Line: wins - 0 losses - 1
# Gladiatrons: wins - 0 losses - 1
# Sir Gilbert: wins - 2 losses - 1
# Laglor: wins - 0 losses - 1
# Major Q9: wins - 4 losses - 1
# Marcu Esenwein: wins - 0 losses - 1
# Eldgrim the Viking Champion: wins - 0 losses - 1
# Sonya Esenwein: wins - 0 losses - 1
# Tor-Kul-Na: wins - 14 losses - 1
# Thorgrim the Viking Champion: wins - 0 losses - 1
# Me-Burq-Sa: wins - 0 losses - 1
# Axegrinders of Burning Forge: wins - 0 losses - 1
# 10th Regiment of Foot: wins - 0 losses - 1
# Tarn Viking Warriors: wins - 0 losses - 1
# Atlega the Kyrie Warrior: wins - 0 losses - 1
# Marcus Decimus Gallus: wins - 0 losses - 1
# Sentinals of Jandar: wins - 0 losses - 1
# Syvarris: wins - 0 losses - 1
# Minions of Utgar: wins - 0 losses - 1
# Alastair MacDirk: wins - 0 losses - 1
# Kaemon Awa: wins - 0 losses - 1
# Cyprien Esenwein: wins - 0 losses - 1
# Zelrig: wins - 1 losses - 1
# Nilfheim: wins - 17 losses - 1
# Sonlen: wins - 0 losses - 1
# Sir Hawthorne: wins - 0 losses - 1
# Braxas: wins - 0 losses - 1
# Theracus: wins - 0 losses - 1
# Sacred Band: wins - 0 losses - 1
# Shiori: wins - 0 losses - 1
# Roman Legionnaires: wins - 0 losses - 1
# Marro Dividers: wins - 0 losses - 1
# Sgt. Drake Alexander: wins - 0 losses - 1
# Brave Arrow: wins - 0 losses - 1
# Zombies of Morindan: wins - 0 losses - 1
# Zetacron: wins - 0 losses - 1
# Mohican River Tribe: wins - 0 losses - 1
# Capuan Gladiators: wins - 0 losses - 1
# Crixus: wins - 0 losses - 1
# Migol Ironwill: wins - 0 losses - 1
# Venoc Warlord: wins - 3 losses - 1
# Raelin the Kyrie Warrior: wins - 0 losses - 1
# Krug: wins - 0 losses - 1
# Spartacus: wins - 18 losses - 1
# Charos: wins - 0 losses - 1
# Otonashi: wins - 0 losses - 1
# Swog Rider: wins - 0 losses - 1
# Guilty McCreech: wins - 0 losses - 1
# Venoc Vipers: wins - 0 losses - 1
# Omnicron Repulsors: wins - 0 losses - 1
# Blade Gruts: wins - 0 losses - 1
# Arrow Gruts: wins - 0 losses - 1
# Nerak the Glacian Swog Rider: wins - 0 losses - 1
# Ne-Gok-Sa: wins - 0 losses - 1
# Warriors of Ashra: wins - 0 losses - 1
# Marro Drones: wins - 0 losses - 1
# Arkmer: wins - 0 losses - 1
# Aubrien Archers: wins - 0 losses - 1
# James Murphy: wins - 0 losses - 1
# Mimring: wins - 0 losses - 1
# Concan the Kyrie Warrior: wins - 0 losses - 1
# Marrden Hounds: wins - 2 losses - 1
# Omnicron Snipers: wins - 0 losses - 1
# Master Win Chiu Woo: wins - 8 losses - 1
# Marro Warriors: wins - 0 losses - 1
# Marro Stingers: wins - 0 losses - 1
# Marro Hive: wins - 0 losses - 1
# Marro Drudge: wins - 0 losses - 1
# Microcorp Agents: wins - 0 losses - 1
# Protectors of Ullar: wins - 0 losses - 1
# Marrden Nagrubs: wins - 0 losses - 1
# Brunak: wins - 5 losses - 1
# Tagawa Samurai: wins - 0 losses - 1
# Nakita Agents: wins - 0 losses - 1
# Ulginesh: wins - 0 losses - 1
# Kyntela Gwyn: wins - 0 losses - 1
# Major Q10: wins - 9 losses - 1
# Ashigaru Harquebus: wins - 0 losses - 1
# Tagawa Samurai Archers: wins - 0 losses - 1
# Johnny "Shotgun" Sullivan: wins - 0 losses - 1
# Armoc Vipers: wins - 0 losses - 1
# Anubian Wolves: wins - 0 losses - 1
# Krav Maga Agents: wins - 0 losses - 1
# Kelda the Kyrie Warrior: wins - 0 losses - 1
# Emirroon: wins - 0 losses - 1
# Retiarius: wins - 4 losses - 1
# Sir Denrick: wins - 0 losses - 1
# Quesatch Hunters: wins - 0 losses - 1
# Ornak: wins - 0 losses - 1
# Kozuke Samurai: wins - 2 losses - 1
# Jorhdawn: wins - 0 losses - 1
# Granite Guardians: wins - 1 losses - 1
# Wo-Sa-Ga: wins - 21 losses - 1
# Su-Bak-Na: wins - 0 losses - 1
# Izumi Samurai: wins - 0 losses - 1
# Taelord the Kyrie Warrior: wins - 0 losses - 1
# Kato Katsuro: wins - 0 losses - 1
# Fyorlag Spiders: wins - 0 losses - 1
# Ashigaru Yari: wins - 0 losses - 1
# Wolves of Badru: wins - 0 losses - 1
# MacDirk Warriors: wins - 0 losses - 1
# Kumiko: wins - 0 losses - 1
# Grimnak: wins - 0 losses - 1
# Chardris: wins - 0 losses - 1
# Tornak: wins - 0 losses - 1
# Morsbane: wins - 0 losses - 1
# Gurei-Oni: wins - 0 losses - 1
# Finn the Viking Champion: wins - 0 losses - 1
# Deathstalkers: wins - 0 losses - 1
# Valguard: wins - 0 losses - 1
# Ninjas of the Northern Wind: wins - 0 losses - 1
# Tul-Bak-Ra: wins - 0 losses - 1
# Sir Dupuis: wins - 0 losses - 1
# Sujoah: wins - 2 losses - 1
# Dumutef Guard: wins - 0 losses - 1
# Deathwalker 9000: wins - 11 losses - 1
# Rechets of Bogdan: wins - 0 losses - 1
# Iskra Esenwein: wins - 0 losses - 1
# Khosumet the Darklord: wins - 0 losses - 1
# Shaolin Monks: wins - 0 losses - 1
# Saylind the Kyrie Warrior: wins - 0 losses - 1
# Parmenio: wins - 0 losses - 1
# Gorillanators: wins - 0 losses - 1
# Elite Onyx Vipers: wins - 0 losses - 1
# Kee-Mo-Shi: wins - 0 losses - 1
# Sudema: wins - 0 losses - 1
# Jotun: wins - 22 losses - 0
# Roman Archers: wins - 0 losses - 1
# Dzu-Teh: wins - 0 losses - 1
# Warden 816: wins - 0 losses - 1
# Empress Kiova: wins - 0 losses - 1
# Shades of Bleakewood: wins - 0 losses - 1
# Acolarh: wins - 0 losses - 1
# Templar Cavalry: wins - 0 losses - 1
# Runa: wins - 0 losses - 1
# Grok Riders: wins - 0 losses - 1
# Deathwalker 8000: wins - 0 losses - 1
# The Einar Imperium: wins - 0 losses - 1
# Deadeye Dan: wins - 0 losses - 1
# Obsidian Guards: wins - 0 losses - 1
# Moriko: wins - 0 losses - 1
# Major X17: wins - 0 losses - 1
# Airborne Elite: wins - 0 losses - 1
# Agent Shaken: wins - 0 losses - 1
# Agent Carr: wins - 0 losses - 1
# Dünd: wins - 0 losses - 1
# Deathwalker 7000: wins - 0 losses - 1
# Hatamoto Taro: wins - 0 losses - 1

# %%
Path(f'output/{trials}').mkdir(parents=True, exist_ok=True)
pickle.dump(cards, open(f'output/{trials}/{datetime.now().isoformat(timespec="seconds")}.p', 'wb'))

# %%
for card in sorted(cards, key=lambda card: cards[card].wins["total"], reverse=True):
    print(f'{cards[card].name}: wins - {cards[card].wins["total"]}')
# Out:
# Jotun: wins - 22
# Wo-Sa-Ga: wins - 21
# Spartacus: wins - 18
# Nilfheim: wins - 17
# Tor-Kul-Na: wins - 14
# Deathwalker 9000: wins - 11
# Major Q10: wins - 9
# Master Win Chiu Woo: wins - 8
# Brunak: wins - 5
# Knights of Weston: wins - 4
# Major Q9: wins - 4
# Retiarius: wins - 4
# Zettian Guards: wins - 3
# Venoc Warlord: wins - 3
# Sir Gilbert: wins - 2
# Marrden Hounds: wins - 2
# Kozuke Samurai: wins - 2
# Sujoah: wins - 2
# Zelrig: wins - 1
# Granite Guardians: wins - 1
# Deathreavers: wins - 0
# Isamu: wins - 0
# Blastatrons: wins - 0
# Heavy Gruts: wins - 0
# 4th Massachusetts Line: wins - 0
# Gladiatrons: wins - 0
# Laglor: wins - 0
# Marcu Esenwein: wins - 0
# Eldgrim the Viking Champion: wins - 0
# Sonya Esenwein: wins - 0
# Thorgrim the Viking Champion: wins - 0
# Me-Burq-Sa: wins - 0
# Axegrinders of Burning Forge: wins - 0
# 10th Regiment of Foot: wins - 0
# Tarn Viking Warriors: wins - 0
# Atlega the Kyrie Warrior: wins - 0
# Marcus Decimus Gallus: wins - 0
# Sentinals of Jandar: wins - 0
# Syvarris: wins - 0
# Minions of Utgar: wins - 0
# Alastair MacDirk: wins - 0
# Kaemon Awa: wins - 0
# Cyprien Esenwein: wins - 0
# Sonlen: wins - 0
# Sir Hawthorne: wins - 0
# Braxas: wins - 0
# Theracus: wins - 0
# Sacred Band: wins - 0
# Shiori: wins - 0
# Roman Legionnaires: wins - 0
# Marro Dividers: wins - 0
# Sgt. Drake Alexander: wins - 0
# Brave Arrow: wins - 0
# Zombies of Morindan: wins - 0
# Zetacron: wins - 0
# Mohican River Tribe: wins - 0
# Capuan Gladiators: wins - 0
# Crixus: wins - 0
# Migol Ironwill: wins - 0
# Raelin the Kyrie Warrior: wins - 0
# Krug: wins - 0
# Charos: wins - 0
# Otonashi: wins - 0
# Swog Rider: wins - 0
# Guilty McCreech: wins - 0
# Venoc Vipers: wins - 0
# Omnicron Repulsors: wins - 0
# Blade Gruts: wins - 0
# Arrow Gruts: wins - 0
# Nerak the Glacian Swog Rider: wins - 0
# Ne-Gok-Sa: wins - 0
# Warriors of Ashra: wins - 0
# Marro Drones: wins - 0
# Arkmer: wins - 0
# Aubrien Archers: wins - 0
# James Murphy: wins - 0
# Mimring: wins - 0
# Concan the Kyrie Warrior: wins - 0
# Omnicron Snipers: wins - 0
# Marro Warriors: wins - 0
# Marro Stingers: wins - 0
# Marro Hive: wins - 0
# Marro Drudge: wins - 0
# Microcorp Agents: wins - 0
# Protectors of Ullar: wins - 0
# Marrden Nagrubs: wins - 0
# Tagawa Samurai: wins - 0
# Nakita Agents: wins - 0
# Ulginesh: wins - 0
# Kyntela Gwyn: wins - 0
# Ashigaru Harquebus: wins - 0
# Tagawa Samurai Archers: wins - 0
# Johnny "Shotgun" Sullivan: wins - 0
# Armoc Vipers: wins - 0
# Anubian Wolves: wins - 0
# Krav Maga Agents: wins - 0
# Kelda the Kyrie Warrior: wins - 0
# Emirroon: wins - 0
# Sir Denrick: wins - 0
# Quesatch Hunters: wins - 0
# Ornak: wins - 0
# Jorhdawn: wins - 0
# Su-Bak-Na: wins - 0
# Izumi Samurai: wins - 0
# Taelord the Kyrie Warrior: wins - 0
# Kato Katsuro: wins - 0
# Fyorlag Spiders: wins - 0
# Ashigaru Yari: wins - 0
# Wolves of Badru: wins - 0
# MacDirk Warriors: wins - 0
# Kumiko: wins - 0
# Grimnak: wins - 0
# Chardris: wins - 0
# Tornak: wins - 0
# Morsbane: wins - 0
# Gurei-Oni: wins - 0
# Finn the Viking Champion: wins - 0
# Deathstalkers: wins - 0
# Valguard: wins - 0
# Ninjas of the Northern Wind: wins - 0
# Tul-Bak-Ra: wins - 0
# Sir Dupuis: wins - 0
# Dumutef Guard: wins - 0
# Rechets of Bogdan: wins - 0
# Iskra Esenwein: wins - 0
# Khosumet the Darklord: wins - 0
# Shaolin Monks: wins - 0
# Saylind the Kyrie Warrior: wins - 0
# Parmenio: wins - 0
# Gorillanators: wins - 0
# Elite Onyx Vipers: wins - 0
# Kee-Mo-Shi: wins - 0
# Sudema: wins - 0
# Roman Archers: wins - 0
# Dzu-Teh: wins - 0
# Warden 816: wins - 0
# Empress Kiova: wins - 0
# Shades of Bleakewood: wins - 0
# Acolarh: wins - 0
# Templar Cavalry: wins - 0
# Runa: wins - 0
# Grok Riders: wins - 0
# Deathwalker 8000: wins - 0
# The Einar Imperium: wins - 0
# Deadeye Dan: wins - 0
# Obsidian Guards: wins - 0
# Moriko: wins - 0
# Major X17: wins - 0
# Airborne Elite: wins - 0
# Agent Shaken: wins - 0
# Agent Carr: wins - 0
# Dünd: wins - 0
# Deathwalker 7000: wins - 0
# Hatamoto Taro: wins - 0
